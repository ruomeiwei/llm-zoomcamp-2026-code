# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from ingest import load_faq_data
documents = load_faq_data()

# %%
docs_llm = [doc for doc in documents if doc['course'] == 'llm-zoomcamp']
print(f'LLM Zoomcamp: {len(docs_llm)} documents')
# Out:
# LLM Zoomcamp: 79 documents

# %%
import time 
from sqlitesearch import TextSearchIndex 

index = TextSearchIndex(
    text_fields= ['question', 'section', 'answer'],
    keyword_fields=['course'],
    db_path = 'faq.db'
)

for doc in docs_llm: 
    index.add(doc)
    print(f"""Added document {doc['question'][:60]}...""")
    time.sleep(0.5)

index.close()
print('Done. Index saved to faq.db')
# Out:
# Added document I just discovered the course. Can I still join?...
# Added document Course: I have registered for the LLM Zoomcamp. When can I e...
# Added document What is the video/zoom link to the stream for the “Office Ho...
# Added document Cloud alternatives with GPU...
# Added document Leaderboard: I am not on the leaderboard / how do I know whi...
# Added document Certificate: Can I follow the course in a self-paced mode an...
# Added document I missed the first homework - can I still get a certificate?...
# Added document Homework: Why does the content keep changing?...
# Added document When will the course be offered next?...
# Added document Are there any lectures/videos? Where are they?...
# Added document WSL2: ResponseError: model requires more system memory (X.X ...
# Added document Server Error (500) When logging in to course homework using ...
# Added document Why are we not using Langchain in the course?...
# Added document OpenAI: Error when running OpenAI responses.create command...
# Added document OpenAI: Error: RateLimitError: Error code: 429 -...
# Added document OpenAI: Error: 'Cannot import name OpenAI from openai'; How ...
# Added document OpenAI: How much will I have to spend to use the Open AI API...
# Added document OpenAI: Do I have to subscribe and pay for Open AI API for t...
# Added document Authentication: Safe and easy way to store and load API keys...
# Added document How to store and load API keys using .env file...
# Added document Authentication: Why is my OPENAI_API_KEY not found in the Ju...
# Added document OpenSource: I am using Groq, and it doesn't provide a tokeni...
# Added document OpenSource: Can I use Groq instead of OpenAI?...
# Added document OpenSource: Can I use open-source alternatives to OpenAI API...
# Added document OpenAI: "RateLimitError 429 / insufficient_quota" — my accou...
# Added document Homework: Returning Empty list after filtering my query (HW ...
# Added document minsearch: SyntaxError "invalid character" when running my d...
# Added document ModuleNotFoundError on import docx in parse-faq.ipynb...
# Added document How do I count tokens for a non-OpenAI model (Gemini, Mistra...
# Added document OpenAI: Why does my token count differ from what OpenAI repo...
# Added document API keys: how do I set them once and not re-export every ter...
# Added document Ollama: How to install Ollama?...
# Added document Connection refused error on prompting the ollam RAG?...
# Added document Any free models with tool use support?...
# Added document Agents: "RuntimeError: Already running asyncio in this threa...
# Added document I passed a float to my tool, but got a validation error sayi...
# Added document Agents: which non-OpenAI models support tool / function call...
# Added document Install MCP Inspector...
# Added document Agents: "AttributeError: 'str' object has no attribute 'outp...
# Added document Run MCP Inspector...
# Added document Inspect MCP Server...
# Added document How to Solve "RuntimeError: Already running asyncio in this ...
# Added document I am using Azure OpenAI and I am still getting an error of E...
# Added document What are embeddings?...
# Added document Warning: 'model "multi-qa-mpnet-base-dot-v1" was made on sen...
# Added document Why was .dot(...) used directly to compute cosine similarity...
# Added document Vector search: should I embed the question, the answer, or b...
# Added document What is the cosine similarity?...
# Added document Why does cosine similarity reduce to a matrix multiplication...
# Added document Evaluation: "JSONDecodeError: Expecting value" when generati...
# Added document Evaluation: Jupyter kernel crashes when embedding the ground...
# Added document Evaluation: hitting rate limits while generating the ground-...
# Added document In Windows OS: OSError: [WinError 126] The specified module ...
# Added document OperationalError when running python prep.py: psycopg2. Oper...
# Added document How set Pandas to show entire text content in a column. Usef...
# Added document How to normalize vectors in a Pandas DataFrame column (or Pa...
# Added document How to compute the quantile or percentile of Pandas DataFram...
# Added document How can I remove all Docker containers, images, and volumes,...
# Added document Session State: I want the user to only be able to give feedb...
# Added document Docker: When trying to run a streamlit app using docker-comp...
# Added document Is it a group project?...
# Added document Do we submit 2 projects, what does attempt 1 and 2 mean?...
# Added document Does the competition count as the capstone?...
# Added document How is my capstone project going to be evaluated?...
# Added document When and how will we be assigned projects for review/grading...
# Added document I’ve already submitted my project. Why can’t I review any pr...
# Added document How can I find some good ideas or datasets for the project?...
# Added document Project: do I need an orchestration tool (Airflow, Mage, Kes...
# Added document Project: how do I evaluate a recommender-style RAG (no obvio...
# Added document Project: my corpus is large (long PDFs, many paragraphs). Wh...
# Added document Project: what does "reproducibility" mean — do reviewers nee...
# Added document Can I use the workshop materials for my own projects or shar...
# Added document How to set up a new dlt project when loading from cloud?...
# Added document There is an error when opening the table using `dbtable = db...
# Added document There is an error when running main(): FileNotFoundError: Ta...
# Added document How do I know which tables are in the db?...
# Added document Does DLT have connectors to ClickHouse or StarRocks?...
# Added document Notebook does not have secret access or 401 Client Error: Un...
# Added document Error: How to fix requests library only installs v2.28 inste...
# Done. Index saved to faq.db
